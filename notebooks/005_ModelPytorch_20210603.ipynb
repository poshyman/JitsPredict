# %%
import os
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2 as cv
from IPython.display import Image
import shutil

import torch
import random
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np

random.seed(108)

# %%
cd "C:\\Users\\61498\\Documents\\GitHub\\JitsPredict\\data\\processed\\"
# Out:
# C:\Users\61498\Documents\GitHub\JitsPredict\data\processed

# %%
images = [os.path.join('images\\input_scaled_2\\', x) for x in os.listdir('images\\input_scaled_2\\')]
annotations = [os.path.join('annotations\\input_scaled_2\\', x) for x in os.listdir('annotations\\input_scaled_2\\') if x[-3:] == "txt"]

# %%
annotations
# Out:
# ['annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16410.txt',
#  'annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16440.txt',
#  'annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16470.txt',
#  'annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16500.txt',
#  'annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16530.txt',
#  'annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16560.txt',
#  'annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16590.txt',
#  'annotations\\input_scaled_2\\2017ADCCWorldChampionshipDay1_Men_+99_1stround_CaseyHellenbergvsTomDeBlass_16620.txt',
# ...

# %%
# Split the dataset into train-valid-test splits 
train_images, val_images, train_annotations, val_annotations = train_test_split(images, annotations, test_size = 0.2, random_state = 1)
val_images, test_images, val_annotations, test_annotations = train_test_split(val_images, val_annotations, test_size = 0.5, random_state = 1)

# %%
os.mkdir('images\\train')  
os.mkdir('images\\val')
os.mkdir('images\\test')
os.mkdir('annotations\\train')
os.mkdir('annotations\\val')
os.mkdir('annotations\\test')

# %%
shutil.copy(train_images[0], 'images\\train')
# Out:
# 'images\\train\\2020WNOCraigJonesvsRonaldoJuniorFullEventReplay1080p_211170.jpg'

# %%
def move_files_to_folder(list_of_files, destination_folder):
    for f in list_of_files:
        try:
            shutil.copy(f, destination_folder)
        except:
            print(f)
            #assert False

# %%
move_files_to_folder(train_images, 'images\\train')
move_files_to_folder(val_images, 'images\\val')
move_files_to_folder(test_images, 'images\\test')
move_files_to_folder(train_annotations, 'annotations\\train')
move_files_to_folder(val_annotations, 'annotations\\val')
move_files_to_folder(test_annotations, 'annotations\\test')
